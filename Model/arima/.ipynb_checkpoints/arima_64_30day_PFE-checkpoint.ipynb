# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_squared_log_error
from matplotlib import ticker
import matplotlib.pyplot as plt
from pmdarima.arima import auto_arima

# %%
df = pd.read_csv("PFE-Pfizer.csv")
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2019-03-01  41.375713  41.546490  41.072105  41.138519  33.767422
# 1     2019-03-04  41.214420  41.356735  40.683113  40.863377  33.541576
# 2     2019-03-05  40.882355  41.034157  40.654648  40.692600  33.401398
# 3     2019-03-06  40.626186  40.673622  39.487667  39.715370  32.599270
# 4     2019-03-07  39.715370  39.743832  39.136623  39.269451  32.233242
# ...          ...        ...        ...        ...        ...        ...
# 1254  2024-02-23  27.750000  28.090000  27.690001  27.760000  27.760000
# 1255  2024-02-26  27.670000  27.670000  27.070000  27.180000  27.180000
# 1256  2024-02-27  27.120001  27.200001  26.809999  26.889999  26.889999
# 1257  2024-02-28  26.959999  27.240000  26.820000  27.040001  27.040001
# 1258  2024-02-29  27.070000  27.190001  26.549999  26.559999  26.559999
#
#         Volume
# 0     26667781
# 1     22805820
# 2     26529812
# 3     22410359
# 4     29046132
# ...        ...
# 1254  33182600
# 1255  45685500
# 1256  38598400
# 1257  31010200
# 1258  54643200
#
# [1259 rows x 7 columns]

# %% [markdown]
# ## Reset index

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set the 'Date' column as the index value
df.set_index('Date', inplace=True)

# %%
# Select the Close column as the dependent variable
df_Close = df[['Close']]
df_Close = df_Close.reset_index(drop=True)

# %% [markdown]
# ## Data normalization

# %%
# Min-max normalization
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(np.array(df_Close))

# %% [markdown]
# ## Data splitting

# %%
# Split the data into training, validation and test dataset in a ratio of 6:4
train_size = int(0.6 * len(data_scaled))
test_size = len(data_scaled) - train_size

train_data = data_scaled[:train_size]
test_data = data_scaled[train_size:]

# %% [markdown]
# ## Model training and testing

# %% [markdown]
# ## Training process

# %%
# Preparing training data
x_train = np.arange(train_size).reshape(-1, 1)
y_train = train_data.reshape(-1)

# %%
# Find the best ARIMA model using auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-3761.786, Time=0.90 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-3750.234, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-3757.342, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-3756.534, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-3752.118, Time=0.11 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-3761.582, Time=0.95 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-3754.424, Time=0.60 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-3771.541, Time=0.96 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-3762.337, Time=0.17 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-3758.711, Time=1.15 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-3762.863, Time=1.18 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-3772.669, Time=0.98 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-3762.376, Time=0.43 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=-3768.853, Time=1.14 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-3760.295, Time=0.69 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=-3757.015, Time=1.15 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-3774.579, Time=0.42 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-3764.192, Time=0.12 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-3763.670, Time=0.29 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=-3764.804, Time=0.63 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=-3769.770, Time=0.59 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-3763.502, Time=0.39 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=-3762.196, Time=0.36 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=-3774.285, Time=0.55 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=-3770.693, Time=0.83 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 15.114 seconds

# %%
# Fit the model
model.fit(y_train)
# Out:
# ARIMA(order=(2, 1, 3), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %% [markdown]
# ## Validate Processing

# %% [markdown]
# ## Testing Processing

# %%
x_test = np.array(range(train_size, len(data_scaled))).reshape(-1, 1)
y_test = np.array(test_data).reshape(-1)
y_pred = model.predict(n_periods=len(y_test))

# %% [markdown]
# ## Evaluate Model

# %%
# Evaluate the accuracy of test
y_test = scaler.inverse_transform(np.array([y_test]).reshape(-1, 1))
y_pred = scaler.inverse_transform(np.array([y_pred]).reshape(-1, 1))

test_mape = mean_absolute_percentage_error(y_test, y_pred)
test_mse = mean_squared_error(y_test, y_pred)
test_rmse = np.sqrt(test_mse)
test_msle = mean_squared_log_error(y_test, y_pred)

print(f"MAPE on Test dataset: ", test_mape)
print(f"RMSE on Test dataset: ", test_rmse)
print(f"MSLE on Test dataset: ", test_msle)
# Out:
# MAPE on Test dataset:  0.2392587660172085
# RMSE on Test dataset:  10.268261117094792
# MSLE on Test dataset:  0.06585997482489273

# %% [markdown]
# # Predicting the next 30 days

# %% [markdown]
# ## Preparing the prediction data

# %%
# The process of creating index predict next 30 days
last_index = df_Close.index[-1]

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index + 1, last_index + 31)).reshape(-1, 1)

# %% [markdown]
# ## Prediction process

# %%
# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))
y_next_30_days = scaler.inverse_transform(np.array([y_next_30_days]).reshape(-1, 1))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days.flatten())
# Out:
# Predicted closing prices for the next 30 days:
# [47.31057727 47.2904472  47.43828838 47.38681144 47.47297073 47.42371352
#  47.47936045 47.43978989 47.47791932 47.44798588 47.474908   47.45280682
#  47.47208841 47.45593839 47.46983848 47.45809066 47.46814094 47.45961254
#  47.46688895 47.46070326 47.46597452 47.4614898  47.46530949 47.46205858
#  47.46482675 47.4624704  47.46447663 47.46276874 47.46422279 47.46298493]

# %% [markdown]
# ## Preparing the forecast date index

# %%
# Get the last date from the current index
last_date = df.index[-1]

# Add one day to the last date
next_date = last_date + pd.DateOffset(days=1)

# Create a list of indices starting from the next date for 30 days
index_next_30_days = pd.date_range(start=next_date, periods=30).tolist()

# %% [markdown]
# ## Visualization

# %%
# Drawing
plt.figure(figsize=(16, 5))

plt.plot(df.index[:train_size], scaler.inverse_transform(np.array([y_train]).reshape(-1, 1)))
plt.plot(df.index[train_size:], y_test)
plt.plot(df.index[train_size:], y_pred)
plt.plot(index_next_30_days, y_next_30_days)

plt.legend(['Train', 'Test', 'PredictTest', 'Next30Day'])
plt.grid()
plt.title(f"Pfizer Closing Price Data from {df.index[0].strftime('%Y-%m-%d')} to {index_next_30_days[-1].strftime('%Y-%m-%d')}")
plt.xlabel("Date")
plt.ylabel("Close value")
plt.savefig('image/ARIMA_64_30day_PFE.png')
plt.show()
