# %%
import datetime as dt
import pandas as pd
import numpy as np
from numpy import arange
import matplotlib.pyplot as plt
from pandas import read_csv
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV

# %%
import yfinance as yf

start_date = '2019-03-01'
end_date = '2024-06-01'
symbol = 'AZN'

data = yf.download(symbol, start=start_date, end=end_date)
data.to_csv('AstraZeneca_data.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df = pd.read_csv('AstraZeneca_data.csv')
df1 = df.reset_index()['Open']

# %%
print(df1)
# Out:
# 0       41.610001
# 1       41.730000
# 2       41.560001
# 3       42.360001
# 4       41.610001
#           ...
# 1254    64.959999
# 1255    66.080002
# 1256    65.940002
# 1257    65.459999
# 1258    65.169998
# Name: Open, Length: 1259, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# %%
train_size = int(0.9 * len(df))
test_size = int(0.1 * len(df))

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train
# Out:
# array([[0.12093725, 0.12396065, 0.1196775 , ..., 0.09347441, 0.09070291,
#         0.09700173],
#        [0.12396065, 0.1196775 , 0.1398337 , ..., 0.09070291, 0.09700173,
#         0.08490801],
#        [0.1196775 , 0.1398337 , 0.12093725, ..., 0.09700173, 0.08490801,
#         0.15091958],
#        ...,
#        [0.55857896, 0.58276639, 0.56638953, ..., 0.59611995, 0.60997732,
#         0.59360036],
#        [0.58276639, 0.56638953, 0.58553789, ..., 0.60997732, 0.59360036,
#         0.6296296 ],
#        [0.56638953, 0.58553789, 0.58755355, ..., 0.59360036, 0.6296296 ,
#         0.62660619]])

# %%
model=RandomForestRegressor()

# %%
grid_rf = {
    'n_estimators': [50, 100, 150, 200],
    'max_depth': np.arange(5, 20, 2),
    'min_samples_split': [3, 6, 9],
    'min_samples_leaf': [2, 3, 5, 7],
    'bootstrap': [True, False],
    'random_state': [10, 20, 30, 40]
}
 
rscv = RandomizedSearchCV(estimator=model, param_distributions=grid_rf, cv=3, n_jobs=-1, verbose=2, n_iter=200)
rscv_fit = rscv.fit(X_train, y_train)
best_parameters = rscv_fit.best_params_
print(best_parameters)
# Out:
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=7, min_samples_split=9, n_estimators=50, random_state=2; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=7, min_samples_split=9, n_estimators=50, random_state=2; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=7, min_samples_split=9, n_estimators=50, random_state=2; total time=   0.6s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=10, n_estimators=50, random_state=42; total time=   0.8s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=10, n_estimators=50, random_state=42; total time=   0.9s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=11, min_samples_split=9, n_estimators=100, random_state=30; total time=   1.7s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=11, min_samples_split=9, n_estimators=100, random_state=30; total time=   1.7s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=10, n_estimators=50, random_state=42; total time=   1.0s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=5, min_samples_split=9, n_estimators=50, random_state=2; total time=   1.2s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=11, min_samples_split=9, n_estimators=100, random_state=30; total time=   2.4s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=5, min_samples_split=9, n_estimators=50, random_state=2; total time=   1.4s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=5, min_samples_split=9, n_estimators=50, random_state=2; total time=   1.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=2, n_estimators=50, random_state=30; total time=   1.1s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=2, n_estimators=50, random_state=30; total time=   0.9s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=13, min_samples_split=9, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=2, n_estimators=50, random_state=30; total time=   0.9s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=13, min_samples_split=9, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=13, min_samples_split=9, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=11, min_samples_split=9, n_estimators=20, random_state=1; total time=   0.4s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=11, min_samples_split=9, n_estimators=20, random_state=1; total time=   0.4s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=11, min_samples_split=9, n_estimators=20, random_state=1; total time=   0.4s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.9s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.6s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=1, min_samples_split=2, n_estimators=500, random_state=1; total time=  10.3s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=1, min_samples_split=2, n_estimators=500, random_state=1; total time=  10.1s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=1, min_samples_split=2, n_estimators=500, random_state=1; total time=  10.5s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42; total time=   3.5s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=9, min_samples_split=2, n_estimators=500, random_state=2; total time=  10.2s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=9, min_samples_split=2, n_estimators=500, random_state=2; total time=  10.3s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=9, min_samples_split=2, n_estimators=500, random_state=2; total time=  10.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=7, min_samples_split=10, n_estimators=50, random_state=1; total time=   0.5s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=7, min_samples_split=10, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=7, min_samples_split=10, n_estimators=50, random_state=1; total time=   0.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=30; total time=   2.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=30; total time=   2.5s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=13, min_samples_split=2, n_estimators=100, random_state=1; total time=   1.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=30; total time=   2.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=3, min_samples_split=10, n_estimators=500, random_state=2; total time=   9.7s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=3, min_samples_split=10, n_estimators=500, random_state=2; total time=   9.9s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=5, min_samples_split=10, n_estimators=50, random_state=2; total time=   0.7s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=500, random_state=2; total time=  12.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=13, min_samples_split=2, n_estimators=100, random_state=1; total time=   1.9s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=5, min_samples_split=10, n_estimators=50, random_state=2; total time=   0.7s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=5, min_samples_split=10, n_estimators=50, random_state=2; total time=   0.7s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=13, min_samples_split=2, n_estimators=100, random_state=1; total time=   1.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=2, n_estimators=100, random_state=1; total time=   0.9s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=13, min_samples_split=9, n_estimators=50, random_state=42; total time=   0.5s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=13, min_samples_split=9, n_estimators=50, random_state=42; total time=   0.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=2, n_estimators=100, random_state=1; total time=   1.0s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=13, min_samples_split=9, n_estimators=50, random_state=42; total time=   0.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=2, n_estimators=100, random_state=1; total time=   1.0s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=500, random_state=2; total time=  12.5s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=500, random_state=2; total time=  12.5s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=1, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.6s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=1, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.6s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=1, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.6s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=7, min_samples_split=10, n_estimators=50, random_state=2; total time=   0.6s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=13, min_samples_split=10, n_estimators=50, random_state=2; total time=   0.5s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=7, min_samples_split=10, n_estimators=50, random_state=2; total time=   0.5s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=7, min_samples_split=10, n_estimators=50, random_state=2; total time=   0.7s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=13, min_samples_split=10, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=13, min_samples_split=10, n_estimators=50, random_state=2; total time=   0.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=5, min_samples_split=9, n_estimators=100, random_state=1; total time=   0.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=5, min_samples_split=9, n_estimators=100, random_state=1; total time=   0.8s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=3, min_samples_split=10, n_estimators=500, random_state=2; total time=  10.3s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=9, min_samples_split=9, n_estimators=20, random_state=2; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=9, min_samples_split=9, n_estimators=20, random_state=2; total time=   0.1s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=9, min_samples_split=10, n_estimators=100, random_state=30; total time=   0.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=5, min_samples_split=9, n_estimators=100, random_state=1; total time=   0.9s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=9, min_samples_split=9, n_estimators=20, random_state=2; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=13, min_samples_split=9, n_estimators=20, random_state=1; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=13, min_samples_split=9, n_estimators=20, random_state=1; total time=   0.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=13, min_samples_split=9, n_estimators=20, random_state=1; total time=   0.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=9, min_samples_split=10, n_estimators=100, random_state=30; total time=   0.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.1s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=9, min_samples_split=10, n_estimators=100, random_state=30; total time=   0.9s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=3, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=3, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.5s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=3, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.5s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=30; total time=   9.1s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=30; total time=   9.6s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=30; total time=   9.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=9, n_estimators=50, random_state=42; total time=   0.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=9, n_estimators=50, random_state=42; total time=   0.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=9, n_estimators=50, random_state=42; total time=   0.7s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=13, min_samples_split=9, n_estimators=500, random_state=1; total time=   8.9s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=13, min_samples_split=9, n_estimators=500, random_state=1; total time=   9.0s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=13, min_samples_split=9, n_estimators=500, random_state=1; total time=   8.9s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=11, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.8s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=11, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.7s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=11, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.9s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=13, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.1s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=13, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.0s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=13, min_samples_split=10, n_estimators=100, random_state=42; total time=   0.9s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=3, min_samples_split=9, n_estimators=500, random_state=42; total time=  12.2s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=3, min_samples_split=9, n_estimators=500, random_state=42; total time=  12.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=7, min_samples_split=2, n_estimators=100, random_state=42; total time=   1.1s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=3, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.5s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=3, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.6s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=7, min_samples_split=2, n_estimators=100, random_state=42; total time=   1.0s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=7, min_samples_split=2, n_estimators=500, random_state=1; total time=   6.0s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=7, min_samples_split=2, n_estimators=500, random_state=1; total time=   5.8s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=3, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.6s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=7, min_samples_split=2, n_estimators=100, random_state=42; total time=   1.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=1; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=1; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=9, min_samples_split=2, n_estimators=50, random_state=30; total time=   0.5s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=9, min_samples_split=2, n_estimators=50, random_state=30; total time=   0.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=1; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=9, min_samples_split=2, n_estimators=50, random_state=30; total time=   0.6s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=7, min_samples_split=2, n_estimators=500, random_state=1; total time=   6.2s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=9, min_samples_split=9, n_estimators=100, random_state=42; total time=   2.0s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=3, min_samples_split=9, n_estimators=500, random_state=42; total time=  12.9s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=9, min_samples_split=9, n_estimators=100, random_state=42; total time=   2.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=7, min_samples_split=9, n_estimators=100, random_state=2; total time=   0.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=7, min_samples_split=9, n_estimators=100, random_state=2; total time=   0.6s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=9, min_samples_split=9, n_estimators=100, random_state=42; total time=   2.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=500, random_state=30; total time=   6.0s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=7, min_samples_split=10, n_estimators=500, random_state=42; total time=   5.8s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=7, min_samples_split=10, n_estimators=500, random_state=42; total time=   6.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=500, random_state=30; total time=   6.4s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=7, min_samples_split=10, n_estimators=500, random_state=42; total time=   6.2s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=7, min_samples_split=9, n_estimators=100, random_state=2; total time=   0.6s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=500, random_state=30; total time=   6.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=9, min_samples_split=10, n_estimators=50, random_state=30; total time=   0.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=9, min_samples_split=10, n_estimators=50, random_state=30; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=1; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=1; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=1; total time=   0.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=9, min_samples_split=10, n_estimators=50, random_state=30; total time=   1.1s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=3, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.7s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=3, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.6s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=3, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.8s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=5, min_samples_split=9, n_estimators=100, random_state=2; total time=   1.3s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=5, min_samples_split=9, n_estimators=100, random_state=2; total time=   1.4s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=5, min_samples_split=9, n_estimators=100, random_state=2; total time=   1.4s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=5, min_samples_split=9, n_estimators=500, random_state=42; total time=   5.5s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=5, min_samples_split=9, n_estimators=500, random_state=42; total time=   6.0s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=13, min_samples_split=10, n_estimators=500, random_state=42; total time=   8.5s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=5, min_samples_split=9, n_estimators=500, random_state=42; total time=   5.9s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=13, min_samples_split=10, n_estimators=500, random_state=42; total time=   8.7s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=13, min_samples_split=10, n_estimators=500, random_state=42; total time=   8.9s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=1, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.4s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=1, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.4s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=1, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.5s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=500, random_state=42; total time=   5.8s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=500, random_state=42; total time=   6.2s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=11, min_samples_split=10, n_estimators=500, random_state=2; total time=   5.2s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=11, min_samples_split=10, n_estimators=500, random_state=2; total time=   5.4s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=11, min_samples_split=2, n_estimators=50, random_state=42; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=500, random_state=42; total time=   6.2s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=5, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.2s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=11, min_samples_split=2, n_estimators=50, random_state=42; total time=   1.0s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=11, min_samples_split=2, n_estimators=50, random_state=42; total time=   1.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=11, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=11, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=11, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.5s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.4s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.4s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.4s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=3, min_samples_split=10, n_estimators=500, random_state=42; total time=  12.9s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.1s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.4s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.1s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=3, min_samples_split=10, n_estimators=500, random_state=42; total time=  13.1s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=13, min_samples_split=9, n_estimators=100, random_state=2; total time=   1.9s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=13, min_samples_split=9, n_estimators=100, random_state=2; total time=   1.9s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=13, min_samples_split=9, n_estimators=100, random_state=2; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=13, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=13, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.8s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=2, n_estimators=50, random_state=1; total time=   1.1s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=11, min_samples_split=10, n_estimators=500, random_state=2; total time=   5.7s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=2, n_estimators=50, random_state=1; total time=   1.0s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=3, min_samples_split=10, n_estimators=500, random_state=42; total time=  13.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=13, min_samples_split=10, n_estimators=100, random_state=1; total time=   2.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=30; total time=   0.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=30; total time=   0.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=30; total time=   0.7s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=2, n_estimators=50, random_state=1; total time=   1.2s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=11, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.5s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=11, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.6s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=3, min_samples_split=2, n_estimators=500, random_state=2; total time=   2.1s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=3, min_samples_split=2, n_estimators=500, random_state=2; total time=   2.5s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=3, min_samples_split=2, n_estimators=500, random_state=2; total time=   2.4s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=7, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=11, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.5s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=7, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=2; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=7, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=2; total time=   0.2s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=2; total time=   0.2s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=30; total time=   0.4s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=30; total time=   0.3s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=30; total time=   0.3s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=9, min_samples_split=10, n_estimators=50, random_state=1; total time=   0.9s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=9, min_samples_split=10, n_estimators=50, random_state=1; total time=   0.9s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.1s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.1s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.1s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=9, min_samples_split=10, n_estimators=50, random_state=1; total time=   1.0s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=7, min_samples_split=10, n_estimators=50, random_state=2; total time=   1.1s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=7, min_samples_split=10, n_estimators=50, random_state=2; total time=   1.1s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=7, min_samples_split=10, n_estimators=50, random_state=2; total time=   1.1s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.7s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.7s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.7s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=500, random_state=2; total time=   9.4s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=500, random_state=2; total time=   9.9s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=500, random_state=2; total time=   9.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=5, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=5, min_samples_split=10, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=5, min_samples_split=10, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=3, min_samples_split=9, n_estimators=20, random_state=2; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=5, min_samples_split=10, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=2; total time=   8.9s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=3, min_samples_split=9, n_estimators=20, random_state=2; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=3, min_samples_split=9, n_estimators=20, random_state=2; total time=   0.4s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=2; total time=   9.6s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=2; total time=   9.7s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=5, min_samples_split=9, n_estimators=50, random_state=2; total time=   1.0s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=11, min_samples_split=10, n_estimators=50, random_state=30; total time=   0.4s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=5, min_samples_split=9, n_estimators=50, random_state=2; total time=   1.1s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=11, min_samples_split=10, n_estimators=50, random_state=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=11, min_samples_split=10, n_estimators=50, random_state=30; total time=   0.4s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=5, min_samples_split=9, n_estimators=50, random_state=2; total time=   1.3s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.2s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=5, min_samples_split=10, n_estimators=50, random_state=2; total time=   0.9s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=5, min_samples_split=10, n_estimators=50, random_state=2; total time=   1.0s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.4s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.3s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=13, min_samples_split=9, n_estimators=100, random_state=1; total time=   0.9s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=5, min_samples_split=10, n_estimators=50, random_state=2; total time=   1.1s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=13, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.0s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=13, min_samples_split=10, n_estimators=50, random_state=1; total time=   1.0s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=13, min_samples_split=9, n_estimators=100, random_state=1; total time=   1.2s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=5, min_samples_split=2, n_estimators=500, random_state=30; total time=   6.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=13, min_samples_split=10, n_estimators=50, random_state=1; total time=   0.9s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=13, min_samples_split=10, n_estimators=50, random_state=1; total time=   0.9s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=5, min_samples_split=2, n_estimators=500, random_state=30; total time=   6.7s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=5, min_samples_split=2, n_estimators=500, random_state=30; total time=   7.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=2, n_estimators=100, random_state=30; total time=   1.8s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=2, n_estimators=100, random_state=30; total time=   1.8s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=2, n_estimators=100, random_state=30; total time=   2.0s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=42; total time=   0.8s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=42; total time=   0.8s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=13, min_samples_split=2, n_estimators=100, random_state=2; total time=   0.4s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=42; total time=   1.0s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=13, min_samples_split=2, n_estimators=100, random_state=2; total time=   0.6s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=13, min_samples_split=2, n_estimators=100, random_state=2; total time=   0.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=10, n_estimators=500, random_state=2; total time=   4.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=10, n_estimators=500, random_state=2; total time=   4.6s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=10, n_estimators=500, random_state=2; total time=   4.5s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.2s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.5s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.7s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.5s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=1, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.8s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=2, n_estimators=100, random_state=2; total time=   1.9s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=2, n_estimators=100, random_state=2; total time=   2.2s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=2, n_estimators=100, random_state=2; total time=   2.2s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=11, min_samples_split=10, n_estimators=500, random_state=1; total time=   9.3s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=11, min_samples_split=10, n_estimators=500, random_state=1; total time=   9.3s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=11, min_samples_split=10, n_estimators=500, random_state=1; total time=   9.7s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=5, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=5, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=5, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=3, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.5s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=3, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.7s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=3, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.5s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=2; total time=   9.1s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=1, min_samples_split=9, n_estimators=500, random_state=1; total time=   7.9s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=1, min_samples_split=9, n_estimators=500, random_state=1; total time=   8.2s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=7, min_samples_split=10, n_estimators=500, random_state=2; total time=   5.4s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=2; total time=   9.4s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=7, min_samples_split=10, n_estimators=500, random_state=2; total time=   5.4s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=2; total time=   9.8s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=13, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.1s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=1, min_samples_split=9, n_estimators=500, random_state=1; total time=   8.8s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=13, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.2s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=13, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.1s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.5s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.6s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=7, min_samples_split=10, n_estimators=500, random_state=2; total time=   5.9s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=13, min_samples_split=2, n_estimators=500, random_state=2; total time=   8.5s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=13, min_samples_split=2, n_estimators=500, random_state=2; total time=   9.2s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=9, min_samples_split=10, n_estimators=500, random_state=1; total time=   5.5s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=13, min_samples_split=2, n_estimators=500, random_state=2; total time=   9.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=9, min_samples_split=2, n_estimators=100, random_state=30; total time=   1.8s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=9, min_samples_split=10, n_estimators=500, random_state=1; total time=   6.2s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=9, min_samples_split=2, n_estimators=100, random_state=30; total time=   1.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=7, min_samples_split=2, n_estimators=500, random_state=42; total time=   9.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=7, min_samples_split=2, n_estimators=500, random_state=42; total time=   9.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=7, min_samples_split=2, n_estimators=500, random_state=42; total time=   9.5s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=9, min_samples_split=2, n_estimators=100, random_state=30; total time=   1.8s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=7, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=7, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=7, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=11, min_samples_split=2, n_estimators=100, random_state=42; total time=   1.8s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=11, min_samples_split=2, n_estimators=100, random_state=42; total time=   1.7s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=11, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=11, min_samples_split=2, n_estimators=100, random_state=42; total time=   1.7s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.4s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=3, min_samples_split=2, n_estimators=100, random_state=42; total time=   1.3s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=9, min_samples_split=10, n_estimators=500, random_state=1; total time=   5.5s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=3, min_samples_split=2, n_estimators=100, random_state=42; total time=   1.5s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=3, min_samples_split=2, n_estimators=100, random_state=42; total time=   1.4s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=30; total time=   0.4s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=30; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.2s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=30; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=1, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.2s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=2; total time=   1.2s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=2; total time=   1.2s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=2; total time=   1.3s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=1; total time=   1.1s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=1; total time=   1.1s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=1; total time=   1.1s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=13, min_samples_split=10, n_estimators=500, random_state=1; total time=   9.0s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.9s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.9s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=13, min_samples_split=10, n_estimators=500, random_state=1; total time=   8.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=13, min_samples_split=10, n_estimators=500, random_state=1; total time=   9.0s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.9s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=5, min_samples_split=9, n_estimators=500, random_state=42; total time=   4.1s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=5, min_samples_split=9, n_estimators=500, random_state=42; total time=   4.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=5, min_samples_split=9, n_estimators=500, random_state=42; total time=   4.5s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=11, min_samples_split=10, n_estimators=50, random_state=42; total time=   0.7s
# ...
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=7, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.3s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=2; total time=   2.0s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=7, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.3s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=1, min_samples_split=10, n_estimators=500, random_state=1; total time=   7.7s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=7, min_samples_split=10, n_estimators=100, random_state=1; total time=   1.3s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=1, min_samples_split=10, n_estimators=500, random_state=1; total time=   7.7s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=5, min_samples_split=9, n_estimators=100, random_state=2; total time=   1.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=9, n_estimators=100, random_state=30; total time=   0.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=9, n_estimators=100, random_state=30; total time=   0.8s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=1, min_samples_split=10, n_estimators=500, random_state=1; total time=   8.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=13, min_samples_split=9, n_estimators=20, random_state=1; total time=   0.1s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=5, min_samples_split=9, n_estimators=100, random_state=2; total time=   1.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=13, min_samples_split=9, n_estimators=20, random_state=1; total time=   0.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=13, min_samples_split=9, n_estimators=20, random_state=1; total time=   0.1s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=13, min_samples_split=9, n_estimators=50, random_state=30; total time=   0.2s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=13, min_samples_split=9, n_estimators=50, random_state=30; total time=   0.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=1, min_samples_split=9, n_estimators=100, random_state=30; total time=   0.8s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.5s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=5, min_samples_split=9, n_estimators=100, random_state=2; total time=   1.6s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=13, min_samples_split=9, n_estimators=50, random_state=30; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=3, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=3, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=3, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=30; total time=   2.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=30; total time=   2.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=30; total time=   2.7s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=9, n_estimators=50, random_state=42; total time=   0.7s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=9, n_estimators=50, random_state=42; total time=   0.7s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=30; total time=   3.3s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=30; total time=   3.4s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=5, min_samples_split=9, n_estimators=50, random_state=42; total time=   0.7s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=9, min_samples_split=9, n_estimators=100, random_state=30; total time=   1.2s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=9, min_samples_split=9, n_estimators=100, random_state=30; total time=   1.2s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=9, min_samples_split=9, n_estimators=100, random_state=30; total time=   1.2s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=7, min_samples_split=9, n_estimators=500, random_state=1; total time=   6.5s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=30; total time=   4.0s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=7, min_samples_split=9, n_estimators=500, random_state=1; total time=   6.4s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=7, min_samples_split=9, n_estimators=500, random_state=1; total time=   6.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=13, min_samples_split=9, n_estimators=100, random_state=2; total time=   0.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=13, min_samples_split=9, n_estimators=100, random_state=2; total time=   0.6s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=3, min_samples_split=10, n_estimators=500, random_state=42; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=13, min_samples_split=9, n_estimators=100, random_state=2; total time=   0.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=3, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=3, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=3, min_samples_split=2, n_estimators=50, random_state=1; total time=   0.6s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=9, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.5s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=9, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.5s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=9, min_samples_split=10, n_estimators=20, random_state=30; total time=   0.6s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=3, min_samples_split=10, n_estimators=500, random_state=42; total time=   2.9s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=3, min_samples_split=10, n_estimators=500, random_state=42; total time=   2.9s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=11, min_samples_split=9, n_estimators=50, random_state=30; total time=   1.1s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.4s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=5, min_samples_split=2, n_estimators=20, random_state=1; total time=   0.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=11, min_samples_split=9, n_estimators=50, random_state=30; total time=   1.2s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=11, min_samples_split=9, n_estimators=50, random_state=30; total time=   1.3s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.5s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.2s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=42; total time=   2.7s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=13, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.2s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=13, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.2s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=3, min_samples_split=9, n_estimators=500, random_state=42; total time=   8.9s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=11, min_samples_split=9, n_estimators=50, random_state=30; total time=   0.2s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=11, min_samples_split=9, n_estimators=50, random_state=30; total time=   0.2s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=13, min_samples_split=10, n_estimators=20, random_state=2; total time=   0.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=11, min_samples_split=9, n_estimators=50, random_state=30; total time=   0.2s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=3, min_samples_split=9, n_estimators=500, random_state=42; total time=   8.7s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.1s
# [CV] END bootstrap=True, max_depth=11, min_samples_leaf=3, min_samples_split=9, n_estimators=500, random_state=42; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=5, min_samples_split=10, n_estimators=20, random_state=42; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=13, min_samples_split=9, n_estimators=20, random_state=30; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=13, min_samples_split=9, n_estimators=20, random_state=30; total time=   0.2s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=13, min_samples_split=9, n_estimators=20, random_state=30; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=11, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=11, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=11, min_samples_split=10, n_estimators=100, random_state=42; total time=   1.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=100, random_state=1; total time=   1.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=100, random_state=1; total time=   1.1s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=100, random_state=1; total time=   1.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=7, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=7, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=7, min_samples_split=9, n_estimators=20, random_state=42; total time=   0.3s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=9, min_samples_split=10, n_estimators=500, random_state=42; total time=   9.7s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.4s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=9, min_samples_split=10, n_estimators=500, random_state=42; total time=   9.8s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=2, n_estimators=500, random_state=42; total time=   8.7s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=2, n_estimators=500, random_state=42; total time=   8.9s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=2, n_estimators=500, random_state=42; total time=   8.8s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=5, min_samples_split=10, n_estimators=100, random_state=42; total time=   2.3s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=9, min_samples_split=10, n_estimators=500, random_state=42; total time=  10.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=7, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=7, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=7, min_samples_split=2, n_estimators=20, random_state=42; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=9, min_samples_split=2, n_estimators=100, random_state=2; total time=   1.2s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=9, min_samples_split=2, n_estimators=100, random_state=2; total time=   1.2s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=9, min_samples_split=2, n_estimators=100, random_state=2; total time=   1.2s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=30; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=30; total time=   0.5s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=2; total time=   0.3s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=30; total time=   0.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=2; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=13, min_samples_split=2, n_estimators=20, random_state=2; total time=   0.4s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=13, min_samples_split=2, n_estimators=500, random_state=42; total time=   4.1s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=13, min_samples_split=2, n_estimators=500, random_state=42; total time=   4.0s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=13, min_samples_split=2, n_estimators=500, random_state=42; total time=   4.3s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=30; total time=   9.0s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=30; total time=   9.2s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=11, min_samples_split=2, n_estimators=500, random_state=30; total time=   9.6s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=9, min_samples_split=10, n_estimators=500, random_state=1; total time=   8.0s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=9, min_samples_split=10, n_estimators=500, random_state=1; total time=   7.9s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=9, min_samples_split=10, n_estimators=500, random_state=1; total time=   7.3s
# {'random_state': 30, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 7, 'bootstrap': False}

# %%
best_parameters
# Out:
# {'random_state': 30,
#  'n_estimators': 100,
#  'min_samples_split': 10,
#  'min_samples_leaf': 1,
#  'max_depth': 7,
#  'bootstrap': False}

# %%
model = RandomForestRegressor(n_estimators=best_parameters['n_estimators'], random_state=best_parameters['random_state'], min_samples_split=best_parameters['min_samples_split'],
                              min_samples_leaf=best_parameters['min_samples_leaf'], max_depth=best_parameters['max_depth'], bootstrap=best_parameters['bootstrap'])
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=7, min_samples_split=10,
#                       random_state=30)

# %%
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)

# %%
# Chuẩn hóa dữ liệu dự đoán
train_predict = scaler.inverse_transform(train_predict.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1))

# %%
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_train = scaler.inverse_transform(y_train.reshape(-1, 1))

# %%
print("Mean Absolute Error:", round(metrics.mean_absolute_error(y_test, y_pred), 4))
print("Mean Squared Error:", round(metrics.mean_squared_error(y_test, y_pred), 4))
print("Root Mean Squared Error:", round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)), 4))
# Out:
# Mean Absolute Error: 4.8766
# Mean Squared Error: 35.2302
# Root Mean Squared Error: 5.9355

# %%
# Dự báo cho 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
temp_input = list(x_input[0])
lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > 100:
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps))
        yhat = model.predict(x_input)
        temp_input.extend(yhat.tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = x_input.reshape((1, n_steps))
        yhat = model.predict(x_input)
        temp_input.extend(yhat.tolist())
        lst_output.extend(yhat.tolist())
        i += 1

lst_output = np.array(lst_output).reshape(-1, 1)

# %%
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred))
prediect_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
plt.plot(prediect_data_index,scaler.inverse_transform(lst_output))
plt.legend(['Train','Test','Predict','Predict30days'])
plt.show()
